# %%
import requests
import pandas as pd
import time
# Get Team Name and associated with its ID in the NHL API JSON request

teamID_url = "https://statsapi.web.nhl.com/api/v1/teams"
   
response = requests.get(teamID_url)

response_json = response.json()
team_info = {}

for team in response_json["teams"]:
    team_id = team["id"]
    team_name = team["name"]
    team_info[team_id] = team_name
   
team_info_df = pd.DataFrame.from_dict(team_info, orient="index", columns=["Team Name"])
team_info_df.reset_index(inplace=True)
team_info_df.columns = ["Team ID", "Team Name"]

team_info_df
# Out:
#     Team ID              Team Name
# 0         1      New Jersey Devils
# 1         2     New York Islanders
# 2         3       New York Rangers
# 3         4    Philadelphia Flyers
# 4         5    Pittsburgh Penguins
# 5         6          Boston Bruins
# 6         7         Buffalo Sabres
# 7         8     Montréal Canadiens
# 8         9        Ottawa Senators
# 9        10    Toronto Maple Leafs
# 10       12    Carolina Hurricanes
# 11       13       Florida Panthers
# 12       14    Tampa Bay Lightning
# 13       15    Washington Capitals
# 14       16     Chicago Blackhawks
# 15       17      Detroit Red Wings
# 16       18    Nashville Predators
# 17       19        St. Louis Blues
# 18       20         Calgary Flames
# 19       21     Colorado Avalanche
# 20       22        Edmonton Oilers
# 21       23      Vancouver Canucks
# 22       24          Anaheim Ducks
# 23       25           Dallas Stars
# 24       26      Los Angeles Kings
# 25       28        San Jose Sharks
# 26       29  Columbus Blue Jackets
# 27       30         Minnesota Wild
# 28       52          Winnipeg Jets
# 29       53        Arizona Coyotes
# 30       54   Vegas Golden Knights
# 31       55         Seattle Kraken

# %%
import requests
import pandas as pd
import time
# Function call to get team stats
def get_team_stats(team_id, season):
    url = f"https://statsapi.web.nhl.com/api/v1/teams/{team_id}?expand=team.stats&season={season}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for request errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for team {team_id}, season {season}: {e}")
        return None
# Function call to extract the team_stat data
def extract_team_stats(data, season_year, team_name, team_id):
    if 'teams' in data and data['teams']:
        team_data = data['teams'][0]
        if 'teamStats' in team_data and team_data['teamStats']:
            team_stats = team_data['teamStats'][0]['splits'][0]['stat']
            team_stats['Team ID'] = team_id
            team_stats['Season Year'] = season_year
            
            return team_stats
    return None

if __name__ == "__main__":
    teamID_url = "https://statsapi.web.nhl.com/api/v1/teams"
    response = requests.get(teamID_url)
    response_json = response.json()

    team_info = {}
    for team in response_json["teams"]:
        team_id = team["id"]
        team_info[team_id] = team_name

    team_info_df = pd.DataFrame.from_dict(team_info, orient="index", columns=["Team Name"])
    team_info_df.reset_index(inplace=True)
    team_info_df.columns = ["Team ID", "Team Name"]

    seasons = [f"{year}{year + 1}" for year in range(1991, 2023)]  

    team_stats_list = []

    for _, row in team_info_df.iterrows():
        team_id = row['Team ID']
        for season in seasons:
            data = get_team_stats(team_id, season)
            if data is not None:
                season_year = f"{int(season[:4])}-{int(season[4:])}"
                team_stats = extract_team_stats(data, season_year, team_name, team_id)
                if team_stats:
                    team_stats_list.append(team_stats)
                else:
                    print(f"No team statistics available for team {team_name} in season {season_year}.")
            time.sleep(0.5)  # Add a delay of 0.5 seconds between API calls

    # Create a DataFrame from the list of team statistics
    team_stats_df = pd.DataFrame(team_stats_list)

    # Reorder the columns with team name, team ID, season, and additional columns at the beginning of the DataFrame
    team_stats_df = team_stats_df[[ "Team ID","Season Year",] + team_stats_df.columns[:-8].tolist()]
# Out:
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 9, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/9?expand=team.stats&season=19911992
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 12, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19911992
# Error fetching data for team 12, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19921993
# Error fetching data for team 12, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19931994
# Error fetching data for team 12, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19941995
# Error fetching data for team 12, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19951996
# Error fetching data for team 12, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats&season=19961997
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 13, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/13?expand=team.stats&season=19911992
# Error fetching data for team 13, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/13?expand=team.stats&season=19921993
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 14, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/14?expand=team.stats&season=19911992
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 18, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19911992
# Error fetching data for team 18, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19921993
# Error fetching data for team 18, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19931994
# Error fetching data for team 18, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19941995
# Error fetching data for team 18, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19951996
# Error fetching data for team 18, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19961997
# Error fetching data for team 18, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/18?expand=team.stats&season=19971998
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 21, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/21?expand=team.stats&season=19911992
# Error fetching data for team 21, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/21?expand=team.stats&season=19921993
# Error fetching data for team 21, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/21?expand=team.stats&season=19931994
# Error fetching data for team 21, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/21?expand=team.stats&season=19941995
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 24, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/24?expand=team.stats&season=19911992
# Error fetching data for team 24, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/24?expand=team.stats&season=19921993
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 25, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/25?expand=team.stats&season=19911992
# Error fetching data for team 25, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/25?expand=team.stats&season=19921993
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 29, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19911992
# Error fetching data for team 29, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19921993
# Error fetching data for team 29, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19931994
# Error fetching data for team 29, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19941995
# Error fetching data for team 29, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19951996
# Error fetching data for team 29, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19961997
# Error fetching data for team 29, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19971998
# Error fetching data for team 29, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19981999
# Error fetching data for team 29, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/29?expand=team.stats&season=19992000
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 30, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19911992
# Error fetching data for team 30, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19921993
# Error fetching data for team 30, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19931994
# Error fetching data for team 30, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19941995
# Error fetching data for team 30, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19951996
# Error fetching data for team 30, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19961997
# Error fetching data for team 30, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19971998
# Error fetching data for team 30, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19981999
# Error fetching data for team 30, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/30?expand=team.stats&season=19992000
# No team statistics available for team Seattle Kraken in season 2004-2005.
# Error fetching data for team 52, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19911992
# Error fetching data for team 52, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19921993
# Error fetching data for team 52, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19931994
# Error fetching data for team 52, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19941995
# Error fetching data for team 52, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19951996
# Error fetching data for team 52, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19961997
# Error fetching data for team 52, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19971998
# Error fetching data for team 52, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19981999
# Error fetching data for team 52, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=19992000
# Error fetching data for team 52, season 20002001: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20002001
# Error fetching data for team 52, season 20012002: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20012002
# Error fetching data for team 52, season 20022003: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20022003
# Error fetching data for team 52, season 20032004: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20032004
# Error fetching data for team 52, season 20042005: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20042005
# Error fetching data for team 52, season 20052006: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20052006
# Error fetching data for team 52, season 20062007: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20062007
# Error fetching data for team 52, season 20072008: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20072008
# Error fetching data for team 52, season 20082009: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20082009
# Error fetching data for team 52, season 20092010: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20092010
# Error fetching data for team 52, season 20102011: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/52?expand=team.stats&season=20102011
# Error fetching data for team 53, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19911992
# Error fetching data for team 53, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19921993
# Error fetching data for team 53, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19931994
# Error fetching data for team 53, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19941995
# Error fetching data for team 53, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19951996
# Error fetching data for team 53, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19961997
# Error fetching data for team 53, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19971998
# Error fetching data for team 53, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19981999
# Error fetching data for team 53, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=19992000
# Error fetching data for team 53, season 20002001: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20002001
# Error fetching data for team 53, season 20012002: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20012002
# Error fetching data for team 53, season 20022003: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20022003
# Error fetching data for team 53, season 20032004: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20032004
# Error fetching data for team 53, season 20042005: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20042005
# Error fetching data for team 53, season 20052006: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20052006
# Error fetching data for team 53, season 20062007: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20062007
# Error fetching data for team 53, season 20072008: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20072008
# Error fetching data for team 53, season 20082009: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20082009
# Error fetching data for team 53, season 20092010: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20092010
# Error fetching data for team 53, season 20102011: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20102011
# Error fetching data for team 53, season 20112012: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20112012
# Error fetching data for team 53, season 20122013: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20122013
# Error fetching data for team 53, season 20132014: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/53?expand=team.stats&season=20132014
# Error fetching data for team 54, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19911992
# Error fetching data for team 54, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19921993
# Error fetching data for team 54, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19931994
# Error fetching data for team 54, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19941995
# Error fetching data for team 54, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19951996
# Error fetching data for team 54, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19961997
# Error fetching data for team 54, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19971998
# Error fetching data for team 54, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19981999
# Error fetching data for team 54, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=19992000
# Error fetching data for team 54, season 20002001: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20002001
# Error fetching data for team 54, season 20012002: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20012002
# Error fetching data for team 54, season 20022003: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20022003
# Error fetching data for team 54, season 20032004: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20032004
# Error fetching data for team 54, season 20042005: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20042005
# Error fetching data for team 54, season 20052006: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20052006
# Error fetching data for team 54, season 20062007: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20062007
# Error fetching data for team 54, season 20072008: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20072008
# Error fetching data for team 54, season 20082009: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20082009
# Error fetching data for team 54, season 20092010: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20092010
# Error fetching data for team 54, season 20102011: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20102011
# Error fetching data for team 54, season 20112012: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20112012
# Error fetching data for team 54, season 20122013: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20122013
# Error fetching data for team 54, season 20132014: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20132014
# Error fetching data for team 54, season 20142015: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20142015
# Error fetching data for team 54, season 20152016: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20152016
# Error fetching data for team 54, season 20162017: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/54?expand=team.stats&season=20162017
# Error fetching data for team 55, season 19911992: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19911992
# Error fetching data for team 55, season 19921993: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19921993
# Error fetching data for team 55, season 19931994: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19931994
# Error fetching data for team 55, season 19941995: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19941995
# Error fetching data for team 55, season 19951996: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19951996
# Error fetching data for team 55, season 19961997: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19961997
# Error fetching data for team 55, season 19971998: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19971998
# Error fetching data for team 55, season 19981999: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19981999
# Error fetching data for team 55, season 19992000: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=19992000
# Error fetching data for team 55, season 20002001: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20002001
# Error fetching data for team 55, season 20012002: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20012002
# Error fetching data for team 55, season 20022003: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20022003
# Error fetching data for team 55, season 20032004: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20032004
# Error fetching data for team 55, season 20042005: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20042005
# Error fetching data for team 55, season 20052006: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20052006
# Error fetching data for team 55, season 20062007: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20062007
# Error fetching data for team 55, season 20072008: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20072008
# Error fetching data for team 55, season 20082009: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20082009
# Error fetching data for team 55, season 20092010: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20092010
# Error fetching data for team 55, season 20102011: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20102011
# Error fetching data for team 55, season 20112012: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20112012
# Error fetching data for team 55, season 20122013: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20122013
# Error fetching data for team 55, season 20132014: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20132014
# Error fetching data for team 55, season 20142015: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20142015
# Error fetching data for team 55, season 20152016: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20152016
# Error fetching data for team 55, season 20162017: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20162017
# Error fetching data for team 55, season 20172018: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20172018
# Error fetching data for team 55, season 20182019: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20182019
# Error fetching data for team 55, season 20192020: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20192020
# Error fetching data for team 55, season 20202021: 404 Client Error: Not Found for url: https://statsapi.web.nhl.com/api/v1/teams/55?expand=team.stats&season=20202021

# %%
team_stats_df.head(5)
# Out:
#    Team ID Season Year  gamesPlayed  wins  losses  ot  pts ptPctg  \
# 0        1   1991-1992           80    38      31   0   87   54.4
# 1        1   1992-1993           84    40      37   0   87   51.8
# 2        1   1993-1994           84    47      25   0  106   63.1
# 3        1   1994-1995           48    22      18   0   52   54.2
# 4        1   1995-1996           82    37      33   0   86   52.4
#
#    goalsPerGame  goalsAgainstPerGame  ...  powerPlayOpportunities  \
# 0         3.613                3.238  ...                   338.0
# 1         3.667                3.560  ...                   400.0
# 2         3.643                2.619  ...                   333.0
# 3         2.833                2.521  ...                   164.0
# 4         2.622                2.463  ...                   368.0
#
#   penaltyKillPercentage  shotsPerGame  shotsAllowed  winScoreFirst  \
# 0                  81.8       31.1875       28.6250          0.711
# 1                  81.4       33.0238       29.8095          0.641
# 2                  81.1       31.6310       29.0119          0.717
# 3                  81.2       30.0833       25.3750          0.600
# 4                  84.6       32.1585       26.5000          0.643
#
#   winOppScoreFirst  winLeadFirstPer  winLeadSecondPer  winOutshootOpp  \
# 0            0.262            0.793             0.805           0.490
# 1            0.333            0.769             0.838           0.510
# 2            0.368            0.897             0.921           0.607
# 3            0.304            0.667             0.714           0.533
# 4            0.250            0.677             0.774           0.475
#
#    winOutshotByOpp
# 0            0.414
# 1            0.452
# 2            0.444
# 3            0.313
# 4            0.381
#
# [5 rows x 24 columns]

# %%
 # Remove hyphens from the "Season Year" column
team_stats_df["Season Year"] = team_stats_df["Season Year"].str.replace("-", "")
team_stats_df['Season Year'] = team_stats_df["Season Year"].astype(int)
columns_to_convert = ['ptPctg', 'powerPlayPercentage','penaltyKillPercentage']
team_stats_df[columns_to_convert] = team_stats_df[columns_to_convert].astype(float)

team_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Team ID                 854 non-null    int64
#  1   Season Year             854 non-null    int32
#  2   gamesPlayed             854 non-null    int64
#  3   wins                    854 non-null    int64
#  4   losses                  854 non-null    int64
#  5   ot                      854 non-null    int64
#  6   pts                     854 non-null    int64
#  7   ptPctg                  854 non-null    float64
#  8   goalsPerGame            854 non-null    float64
#  9   goalsAgainstPerGame     854 non-null    float64
#  10  evGGARatio              854 non-null    float64
#  11  powerPlayPercentage     854 non-null    float64
#  12  powerPlayGoals          854 non-null    float64
#  13  powerPlayGoalsAgainst   854 non-null    float64
#  14  powerPlayOpportunities  854 non-null    float64
#  15  penaltyKillPercentage   854 non-null    float64
#  16  shotsPerGame            854 non-null    float64
#  17  shotsAllowed            854 non-null    float64
#  18  winScoreFirst           854 non-null    float64
#  19  winOppScoreFirst        854 non-null    float64
#  20  winLeadFirstPer         854 non-null    float64
#  21  winLeadSecondPer        854 non-null    float64
#  22  winOutshootOpp          854 non-null    float64
#  23  winOutshotByOpp         854 non-null    float64
# dtypes: float64(17), int32(1), int64(6)
# memory usage: 156.9 KB

# %%
team_stats_df.rename(columns={
                              "Team ID": "team_id", 
                              "Season Year": "season_id", 
                              "gamesPlayed": "team_stats_gamesPlayed", 
                              "wins": "team_stats_wins", 
                              "losses": "team_stats_losses",
                              "ot": "team_stats_ot",
                              "pts": "team_stats_pts",
                              "ptPctg":"team_stats_ptPctg",
                              "goalsPerGame": "team_stats_goalsPerGame",
                              "goalsAgainstPerGame": "team_stats_goalsAgainstPerGame",
                              "evGGARatio": "team_stats_evGGARatio",
                              "powerPlayPercentage": "team_stats_powerPlayPercentage",
                              "powerPlayGoals": "team_stats_powerPlayGoals",
                              "powerPlayGoalsAgainst": "team_stats_powerPlayGoalsAgainst",
                              "powerPlayOpportunities":"team_stats_powerPlayOpportunities",
                              "penaltyKillPercentage":"team_stats_penaltyKillPercentage",
                              "shotsPerGame":"team_stats_shotsPerGame",
                              "shotsAllowed":"team_stats_shotsAllowed",
                              "winScoreFirst":"team_stats_winScoreFirst",
                              "winOppScoreFirst":"team_stats_winOppScoreFirst",
                              "winLeadFirstPer":"team_stats_winLeadFirstPer",
                              "winLeadSecondPer":"team_stats_winLeadSecondPer",
                              "winOutshootOpp":"team_stats_winOutshootOpp",
                              "winOutshotByOpp":"team_stats_winOutshotByOpp",
                              "faceOffsTaken":"team_stats_faceOffsTaken",
                              "faceOffsWon":"team_stats_faceOffsWon",
                              "faceOffsLost":"team_stats_faceOffsLost",
                              "faceOffWinPercentage":"team_stats_faceOffWinPercentage",
                              "shootingPctg":"team_stats_shootingPctg",
                              "savePctg":"team_stats_savePctg"

                              }, inplace=True)

# %%
team_stats_df.head(5)
# Out:
#    team_id  season_id  team_stats_gamesPlayed  team_stats_wins  \
# 0        1   19911992                      80               38
# 1        1   19921993                      84               40
# 2        1   19931994                      84               47
# 3        1   19941995                      48               22
# 4        1   19951996                      82               37
#
#    team_stats_losses  team_stats_ot  team_stats_pts  team_stats_ptPctg  \
# 0                 31              0              87               54.4
# 1                 37              0              87               51.8
# 2                 25              0             106               63.1
# 3                 18              0              52               54.2
# 4                 33              0              86               52.4
#
#    team_stats_goalsPerGame  team_stats_goalsAgainstPerGame  ...  \
# 0                    3.613                           3.238  ...
# 1                    3.667                           3.560  ...
# 2                    3.643                           2.619  ...
# 3                    2.833                           2.521  ...
# 4                    2.622                           2.463  ...
#
#    team_stats_powerPlayOpportunities  team_stats_penaltyKillPercentage  \
# 0                              338.0                              81.8
# 1                              400.0                              81.4
# 2                              333.0                              81.1
# 3                              164.0                              81.2
# 4                              368.0                              84.6
#
#    team_stats_shotsPerGame  team_stats_shotsAllowed  team_stats_winScoreFirst  \
# 0                  31.1875                  28.6250                     0.711
# 1                  33.0238                  29.8095                     0.641
# 2                  31.6310                  29.0119                     0.717
# 3                  30.0833                  25.3750                     0.600
# 4                  32.1585                  26.5000                     0.643
#
#    team_stats_winOppScoreFirst  team_stats_winLeadFirstPer  \
# 0                        0.262                       0.793
# 1                        0.333                       0.769
# 2                        0.368                       0.897
# 3                        0.304                       0.667
# 4                        0.250                       0.677
#
#    team_stats_winLeadSecondPer  team_stats_winOutshootOpp  \
# 0                        0.805                      0.490
# 1                        0.838                      0.510
# 2                        0.921                      0.607
# 3                        0.714                      0.533
# 4                        0.774                      0.475
#
#    team_stats_winOutshotByOpp
# 0                       0.414
# 1                       0.452
# 2                       0.444
# 3                       0.313
# 4                       0.381
#
# [5 rows x 24 columns]

# %%
team_stats_df.insert(0,'team_stat_id', '')
team_stats_df.head(5)
# Out:
#   team_stat_id  team_id  season_id  team_stats_gamesPlayed  team_stats_wins  \
# 0                     1   19911992                      80               38
# 1                     1   19921993                      84               40
# 2                     1   19931994                      84               47
# 3                     1   19941995                      48               22
# 4                     1   19951996                      82               37
#
#    team_stats_losses  team_stats_ot  team_stats_pts  team_stats_ptPctg  \
# 0                 31              0              87               54.4
# 1                 37              0              87               51.8
# 2                 25              0             106               63.1
# 3                 18              0              52               54.2
# 4                 33              0              86               52.4
#
#    team_stats_goalsPerGame  ...  team_stats_powerPlayOpportunities  \
# 0                    3.613  ...                              338.0
# 1                    3.667  ...                              400.0
# 2                    3.643  ...                              333.0
# 3                    2.833  ...                              164.0
# 4                    2.622  ...                              368.0
#
#    team_stats_penaltyKillPercentage  team_stats_shotsPerGame  \
# 0                              81.8                  31.1875
# 1                              81.4                  33.0238
# 2                              81.1                  31.6310
# 3                              81.2                  30.0833
# 4                              84.6                  32.1585
#
#    team_stats_shotsAllowed  team_stats_winScoreFirst  \
# 0                  28.6250                     0.711
# 1                  29.8095                     0.641
# 2                  29.0119                     0.717
# 3                  25.3750                     0.600
# 4                  26.5000                     0.643
#
#    team_stats_winOppScoreFirst  team_stats_winLeadFirstPer  \
# 0                        0.262                       0.793
# 1                        0.333                       0.769
# 2                        0.368                       0.897
# 3                        0.304                       0.667
# 4                        0.250                       0.677
#
#    team_stats_winLeadSecondPer  team_stats_winOutshootOpp  \
# 0                        0.805                      0.490
# 1                        0.838                      0.510
# 2                        0.921                      0.607
# 3                        0.714                      0.533
# 4                        0.774                      0.475
#
#    team_stats_winOutshotByOpp
# 0                       0.414
# 1                       0.452
# 2                       0.444
# 3                       0.313
# 4                       0.381
#
# [5 rows x 25 columns]

# %%
   # Save the DataFrame to a CSV file
csv_filename = "team_stats.csv"
team_stats_df.to_csv(csv_filename, index=False,encoding = 'utf-8-sig')
